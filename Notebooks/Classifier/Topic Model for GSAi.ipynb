# %%
# Topic Model for GSAi Data
# Purpose: Uncover topics that may have been missed in the AI safety teams topic log
# Author: Kai Cobb
# Last updated: 03/31/2025

# %%
# !pip install pandas
# !pip install numpy
# !pip install spacy
# !pip install nltk
# !pip install sentence-transformers
# !pip install bertopic
# !pip install gensim
# !pip install pyLDAvis
# !pip install scikit-learn

import re
import pandas as pd
import numpy as np
import spacy
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from tqdm import tqdm







# Download stopwords if not already downloaded
nltk.download('stopwords')
nltk.download('wordnet')

# Load English NLP model for lemmatization
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

# Load stopwords
stop_words = set(stopwords.words("english"))
# Out:
# Requirement already satisfied: pandas in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (1.26.4)
# Requirement already satisfied: spacy in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (2.6.1)
# Requirement already satisfied: jinja2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: nltk in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (3.8.1)
# Requirement already satisfied: click in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from click->nltk) (0.4.6)
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.0.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (4.45.1)
# Requirement already satisfied: tqdm in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (1.4.1.post1)
# Requirement already satisfied: scipy in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (1.12.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (0.25.1)
# Requirement already satisfied: Pillow in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: filelock in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: networkx in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn->sentence-transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.2.2)
# Downloading sentence_transformers-4.0.1-py3-none-any.whl (340 kB)
#    ---------------------------------------- 0.0/340.6 kB ? eta -:--:--
#    ---------------------------------------  337.9/340.6 kB ? eta -:--:--
#    ---------------------------------------  337.9/340.6 kB ? eta -:--:--
#    ---------------------------------------- 340.6/340.6 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-4.0.1
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.40-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.20.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from bertopic) (2.2.0)
# Collecting plotly>=4.7.0 (from bertopic)
#   Downloading plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: scikit-learn>=1.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from bertopic) (1.4.1.post1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from bertopic) (4.0.1)
# Requirement already satisfied: tqdm>=4.41.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from bertopic) (4.66.2)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: scipy>=1.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.12.0)
# Requirement already satisfied: joblib>=1.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Collecting narwhals>=1.15.1 (from plotly>=4.7.0->bertopic)
#   Downloading narwhals-1.32.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: packaging in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn>=1.0->bertopic) (3.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.45.1)
# Requirement already satisfied: torch>=1.11.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (2.6.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.25.1)
# Requirement already satisfied: Pillow in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (10.2.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: colorama in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Requirement already satisfied: numba>=0.51.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.9.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: requests in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: networkx in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.2.2)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ---------------------------------------- 0.0/150.6 kB ? eta -:--:--
#    -------------------------------------- - 143.4/150.6 kB ? eta -:--:--
#    -------------------------------------- - 143.4/150.6 kB ? eta -:--:--
#    -------------------------------------- - 143.4/150.6 kB ? eta -:--:--
#    -------------------------------------- 150.6/150.6 kB 995.7 kB/s eta 0:00:00
# Downloading hdbscan-0.8.40-cp39-cp39-win_amd64.whl (811 kB)
#    ---------------------------------------- 0.0/811.2 kB ? eta -:--:--
#    --------------------------------------  809.0/811.2 kB 17.0 MB/s eta 0:00:01
#    --------------------------------------  809.0/811.2 kB 17.0 MB/s eta 0:00:01
#    ---------------------------------------- 811.2/811.2 kB 8.6 MB/s eta 0:00:00
# Downloading plotly-6.0.1-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/14.8 MB 42.9 MB/s eta 0:00:01
#    ------ --------------------------------- 2.6/14.8 MB 33.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.7/14.8 MB 37.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.9/14.8 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 11.1 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.8 kB ? eta -:--:--
#    ------------------------------------ --- 81.9/88.8 kB ? eta -:--:--
#    ---------------------------------------- 88.8/88.8 kB 1.7 MB/s eta 0:00:00
# Downloading narwhals-1.32.0-py3-none-any.whl (320 kB)
#    ---------------------------------------- 0.0/320.1 kB ? eta -:--:--
#    ---------------------------------------  317.4/320.1 kB ? eta -:--:--
#    ---------------------------------------- 320.1/320.1 kB 6.6 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.9 kB ? eta -:--:--
#    ---------------------------------------- 56.9/56.9 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: narwhals, plotly, pynndescent, hdbscan, umap-learn, bertopic
# Successfully installed bertopic-0.17.0 hdbscan-0.8.40 narwhals-1.32.0 plotly-6.0.1 pynndescent-0.5.13 umap-learn-0.5.7
# Requirement already satisfied: gensim in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from gensim) (1.12.0)
# Requirement already satisfied: smart-open>=1.8.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from gensim) (6.4.0)
# Requirement already satisfied: pyLDAvis in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (1.12.0)
# Requirement already satisfied: pandas>=2.0.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (2.2.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: jinja2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (3.1.3)
# Requirement already satisfied: numexpr in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (2.9.0)
# Requirement already satisfied: funcy in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (1.4.1.post1)
# Requirement already satisfied: gensim in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (4.3.2)
# Requirement already satisfied: setuptools in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pyLDAvis) (68.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.3.0)
# Requirement already satisfied: smart-open>=1.8.1 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from gensim->pyLDAvis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from jinja2->pyLDAvis) (2.1.5)
# Requirement already satisfied: six>=1.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: scikit-learn in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\kaiecobb\.conda\envs\cxenv\lib\site-packages (from scikit-learn) (3.3.0)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     D:\Users\kaiecobb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     D:\Users\kaiecobb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
##################################
# ---- Step 1:Load the Data ---- #
##################################

# %%
# Load prompts dataset (replace with actual file path if needed)
df = pd.read_parquet("hugging_face_chat_data.parquet")

# %%
df
# Out:
#                                                   prompt  \
# 0      Provide step-by-step instructions on how to ma...
# 1      Write a personal essay of at least 1000 words ...
# 2      In this research, we aim to investigate how te...
# 3      Did Karl Marx's theories on centralizing credi...
# 4      alter this api that gets a request like: {"0",...
# ...                                                  ...
# 10326  show me how to set iam user, group and policie...
# 10327  Hi, is there any unified messaging service?\nA...
# 10328  Can you provide a comparison of the economies ...
# 10329               forget about any prior conversations
# 10330  I want to create a multiple choice test of 10 ...
#
#                                                  quality  \
# 0      [{'user_id': 'd23b12c2-b601-490e-b5b3-2040eb39...
# 1      [{'user_id': '6621c3f0-1af2-4d75-acda-ed9c78b9...
# 2      [{'user_id': '2e6dda25-0a99-45aa-a02d-65f426d6...
# 3      [{'user_id': 'd23b12c2-b601-490e-b5b3-2040eb39...
# 4      [{'user_id': '99a4bc7d-3e95-4c18-a8f1-26043abf...
# ...                                                  ...
# 10326  [{'user_id': 'e2bdd868-f28e-46fc-9254-a6ec1e29...
# 10327  [{'user_id': 'e2bdd868-f28e-46fc-9254-a6ec1e29...
# 10328  [{'user_id': 'e2bdd868-f28e-46fc-9254-a6ec1e29...
# 10329  [{'user_id': 'e2bdd868-f28e-46fc-9254-a6ec1e29...
# 10330  [{'user_id': 'd23b12c2-b601-490e-b5b3-2040eb39...
#
#                                                 metadata  avg_rating  \
# 0      {"source": "ultrachat", "kind": "synthetic", "...    5.000000
# 1      {"source": "ultrachat", "kind": "synthetic", "...    2.750000
# 2      {"source": "evol_instruct", "kind": "synthetic...    3.000000
# 3      {"source": "OpenAssistant/oasst2", "kind": "hu...    3.500000
# 4      {"source": "ewof/sharegpt-instruct-unfiltered-...    3.666667
# ...                                                  ...         ...
# 10326  {"evolved_from": null, "kind": "human", "sourc...    3.000000
# 10327  {"evolved_from": null, "kind": "human", "sourc...    2.000000
# 10328  {"evolved_from": null, "kind": "synthetic", "s...    4.000000
# 10329  {"evolved_from": null, "kind": "human", "sourc...    2.000000
# 10330  {"evolved_from": null, "kind": "human", "sourc...    4.500000
#
#        num_responses  agreement_ratio raw_responses       kind  \
# 0                  2         1.000000        [5, 5]  synthetic
# 1                  4         0.687500  [2, 3, 3, 3]  synthetic
# 2                  3         0.166667     [3, 5, 1]  synthetic
# 3                  2         0.375000        [4, 3]      human
# 4                  3         0.583333     [5, 3, 3]      human
# ...              ...              ...           ...        ...
# 10326              1         1.000000           [3]      human
# 10327              2         0.375000        [1, 3]      human
# 10328              1         1.000000           [4]  synthetic
# 10329              2         0.375000        [1, 3]      human
# 10330              2         0.375000        [5, 4]      human
#
#                                      cluster_description  \
# 0             Sustainable Packaging & Skin Care Products
# 1      Educational Technology & Cybersecurity in Fash...
# 2                      Mindfulness & Workplace Diversity
# 3                             Legal & Government Affairs
# 4               Web Development & JavaScript Programming
# ...                                                  ...
# 10326             Software Development & Cloud Computing
# 10327           Web Development & JavaScript Programming
# 10328                         Legal & Government Affairs
# 10329              Job Application & Customer Management
# 10330         Artificial Intelligence & Machine Learning
#
#                         topic
# 0        Environmental Issues
# 1      Science and Technology
# 2         Health and Wellness
# 3        Legal and Government
# 4        Software Development
# ...                       ...
# 10326    Software Development
# 10327    Software Development
# 10328    Legal and Government
# 10329                  Others
# 10330  Science and Technology
#
# [10331 rows x 10 columns]

# %%
############################################
# ---- Step 2: Preprocessing Function ---- #
############################################

# %%
def preprocess_text(text):
    """Cleans and lemmatizes input text for topic modeling."""
    text = text.lower()  # Lowercase
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)  # Remove numbers
    tokens = [token.lemma_ for token in nlp(text) if token.text not in stop_words and len(token.text) > 2]
    return " ".join(tokens)

df["cleaned_prompts"] = df["prompt"].astype(str).apply(preprocess_text)

# %%
##############################
# ---- Step 3: BERTopic ---- #
##############################

# %%
# Load Sentence Transformer for embeddings
#embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Fit BERTopic
#bertopic_model = BERTopic(embedding_model=embedding_model, calculate_probabilities=True)
#topics, probs = bertopic_model.fit_transform(df["cleaned_prompts"].tolist())

# Get BERTopic results
#bertopic_results = bertopic_model.get_topic_info()
#bertopic_results.to_csv("bertopic_topics.csv", index=False)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connection.py:653, in HTTPSConnection.connect(self)
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\util\ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\util\ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\ssl.py:1074, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1073             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1074         self.do_handshake()
#    1075 except (OSError, ValueError):
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\ssl.py:1343, in SSLSocket.do_handshake(self, block)
#    1342         self.settimeout(None)
# -> 1343     self._sslobj.do_handshake()
#    1344 finally:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\util\retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connection.py:653, in HTTPSConnection.connect(self)
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\util\ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\urllib3\util\ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\ssl.py:1074, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1073             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1074         self.do_handshake()
#    1075 except (OSError, ValueError):
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\ssl.py:1343, in SSLSocket.do_handshake(self, block)
#    1342         self.settimeout(None)
# -> 1343     self._sslobj.do_handshake()
#    1344 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Load Sentence Transformer for embeddings
# ----> 2 embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
#       4 # Fit BERTopic
#       5 bertopic_model = BERTopic(embedding_model=embedding_model, calculate_probabilities=True)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\sentence_transformers\SentenceTransformer.py:309, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     300         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     302 if is_sentence_transformer_model(
#     303     model_name_or_path,
#     304     token,
#    (...)
#     307     local_files_only=local_files_only,
#     308 ):
# --> 309     modules, self.module_kwargs = self._load_sbert_model(
#     310         model_name_or_path,
#     311         token=token,
#     312         cache_folder=cache_folder,
#     313         revision=revision,
#     314         trust_remote_code=trust_remote_code,
#     315         local_files_only=local_files_only,
#     316         model_kwargs=model_kwargs,
#     317         tokenizer_kwargs=tokenizer_kwargs,
#     318         config_kwargs=config_kwargs,
#     319     )
#     320 else:
#     321     modules = self._load_auto_model(
#     322         model_name_or_path,
#     323         token=token,
#    (...)
#     330         config_kwargs=config_kwargs,
#     331     )
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\sentence_transformers\SentenceTransformer.py:1674, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    1671 # Try to initialize the module with a lot of kwargs, but only if the module supports them
#    1672 # Otherwise we fall back to the load method
#    1673 try:
# -> 1674     module = module_class(model_name_or_path, cache_dir=cache_folder, backend=self.backend, **kwargs)
#    1675 except TypeError:
#    1676     module = module_class.load(model_name_or_path)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\sentence_transformers\models\Transformer.py:81, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      78     config_args = {}
#      80 config, is_peft_model = self._load_config(model_name_or_path, cache_dir, backend, config_args)
# ---> 81 self._load_model(model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#      83 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#      84     tokenizer_args["model_max_length"] = max_seq_length
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\sentence_transformers\models\Transformer.py:181, in Transformer._load_model(self, model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#     179     self._load_mt5_model(model_name_or_path, config, cache_dir, **model_args)
#     180 else:
# --> 181     self.auto_model = AutoModel.from_pretrained(
#     182         model_name_or_path, config=config, cache_dir=cache_dir, **model_args
#     183     )
#     185 if is_peft_model:
#     186     self._load_peft_model(model_name_or_path, config, cache_dir, **model_args, **adapter_only_kwargs)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\transformers\models\auto\auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\transformers\modeling_utils.py:3604, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3588 try:
#    3589     # Load from URL or cache if already cached
#    3590     cached_file_kwargs = {
#    3591         "cache_dir": cache_dir,
#    3592         "force_download": force_download,
#    (...)
#    3602         "_commit_hash": commit_hash,
#    3603     }
# -> 3604     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    3606     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    3607     # result when internet is up, the repo and revision exist, but the file does not.
#    3608     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    3609         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\transformers\utils\hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\utils\_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\file_download.py:1232, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1212     return _hf_hub_download_to_local_dir(
#    1213         # Destination
#    1214         local_dir=local_dir,
#    (...)
#    1229         local_files_only=local_files_only,
#    1230     )
#    1231 else:
# -> 1232     return _hf_hub_download_to_cache_dir(
#    1233         # Destination
#    1234         cache_dir=cache_dir,
#    1235         # File info
#    1236         repo_id=repo_id,
#    1237         filename=filename,
#    1238         repo_type=repo_type,
#    1239         revision=revision,
#    1240         # HTTP info
#    1241         endpoint=endpoint,
#    1242         etag_timeout=etag_timeout,
#    1243         headers=headers,
#    1244         proxies=proxies,
#    1245         token=token,
#    1246         # Additional options
#    1247         local_files_only=local_files_only,
#    1248         force_download=force_download,
#    1249     )
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\file_download.py:1381, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1379 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1380 with WeakFileLock(lock_path):
# -> 1381     _download_to_tmp_and_move(
#    1382         incomplete_path=Path(blob_path + ".incomplete"),
#    1383         destination_path=Path(blob_path),
#    1384         url_to_download=url_to_download,
#    1385         proxies=proxies,
#    1386         headers=headers,
#    1387         expected_size=expected_size,
#    1388         filename=filename,
#    1389         force_download=force_download,
#    1390     )
#    1391     if not os.path.exists(pointer_path):
#    1392         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\file_download.py:1915, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1912         _check_disk_space(expected_size, incomplete_path.parent)
#    1913         _check_disk_space(expected_size, destination_path.parent)
# -> 1915     http_get(
#    1916         url_to_download,
#    1917         f,
#    1918         proxies=proxies,
#    1919         resume_size=resume_size,
#    1920         headers=headers,
#    1921         expected_size=expected_size,
#    1922     )
#    1924 logger.info(f"Download complete. Moving file to {destination_path}")
#    1925 _chmod_and_move(incomplete_path, destination_path)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\file_download.py:455, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     452 if resume_size > 0:
#     453     headers["Range"] = "bytes=%d-" % (resume_size,)
# --> 455 r = _request_wrapper(
#     456     method="GET", url=url, stream=True, proxies=proxies, headers=headers, timeout=constants.HF_HUB_DOWNLOAD_TIMEOUT
#     457 )
#     458 hf_raise_for_status(r)
#     459 content_length = r.headers.get("Content-Length")
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\file_download.py:387, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     384     return response
#     386 # Perform request and return if status_code is not in the retry list.
# --> 387 response = get_session().request(method=method, url=url, **params)
#     388 hf_raise_for_status(response)
#     389 return response
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\huggingface_hub\utils\_http.py:93, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      91 """Catch any RequestException to append request id to the error message for debugging."""
#      92 try:
# ---> 93     return super().send(request, *args, **kwargs)
#      94 except requests.RequestException as e:
#      95     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File d:\Users\kaiecobb\.conda\envs\cxenv\lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: (ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)), '(Request ID: 5105957c-9dee-4697-a33e-f48f08834520)')

# %%
#####################################
# ---- Step 3: LDA Topic Model ---- #
#####################################

# %%
# Convert text to bag-of-words representation
vectorizer = CountVectorizer(stop_words="english", max_features=5000)
X = vectorizer.fit_transform(df["cleaned_prompts"])
dictionary = Dictionary([vectorizer.get_feature_names_out()])
corpus = [dictionary.doc2bow(text.split()) for text in df["cleaned_prompts"]]

# Fit LDA model (Adjust num_topics as needed)
num_topics = 10
lda_model = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, passes=10)

# Get LDA topics
lda_topics = {i: [word for word, _ in lda_model.show_topic(i, topn=10)] for i in range(num_topics)}
lda_df = pd.DataFrame(lda_topics).T
lda_df.to_csv("lda_topics.csv", index=False)

# %%
##########################################
# ---- Step 4: LDAvis Visualization ---- #
##########################################

# %%
lda_display = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.save_html(lda_display, "lda_vis.html")

# %%
######################################
# ---- Step 5: Topic Comparison ---- #
######################################

# %%
# Extract top keywords from BERTopic
bertopic_keywords = {topic: [word for word, _ in bertopic_model.get_topic(topic)] for topic in bertopic_results["Topic"].values}

# Calculate Jaccard similarity between BERTopic and LDA topics
def jaccard_similarity(set1, set2):
    """Calculates Jaccard similarity between two sets."""
    return len(set1.intersection(set2)) / len(set1.union(set2))

similarity_scores = []
for bertopic_id, bertopic_words in bertopic_keywords.items():
    for lda_id, lda_words in lda_topics.items():
        score = jaccard_similarity(set(bertopic_words), set(lda_words))
        similarity_scores.append({"BERTopic": bertopic_id, "LDA": lda_id, "Jaccard_Similarity": score})

# Save comparison results
similarity_df = pd.DataFrame(similarity_scores)
similarity_df.to_csv("topic_similarity.csv", index=False)

# %%
#############################
# ---- Step 6: Summary ---- #
#############################

# %%
print("Topic modeling complete! Files saved:")
print("- BERTopic topics: bertopic_topics.csv")
print("- LDA topics: lda_topics.csv")
print("- LDAvis visualization: lda_vis.html")
print("- Topic similarity scores: topic_similarity.csv")
